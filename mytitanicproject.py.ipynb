# %%
import pyforest

# %%
Data=pd.read_csv("train.csv")
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data.shape
# Out:
# (891, 12)

# %%
Data.isna().sum() #chaeking how many null values present in dataset #Hear sum will check the null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
Data.describe() #hear describe indicates cont,mean,std,min,25%,50%,75%,max
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Data.info() #info means to know the data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Data.dtypes #This is for to know data type seperately
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
from sklearn import preprocessing  #import Lable encoder
label_encoder=preprocessing.LabelEncoder() #lable_encoder object knows how to understand word labels
Data["Gender"]=lable_encoder.fit_transform(Data["Gender"])
Data["Gender"].value_counts() #convert male as "1" and female as "2"
# Out:
# Gender
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina       0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data=Data.drop(["Ticket","Name","Cabin"],axis=1)
Data
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch     Fare  \
# 0              1         0       3       1  22.0      1      0   7.2500
# 1              2         1       1       0  38.0      1      0  71.2833
# 2              3         1       3       0  26.0      0      0   7.9250
# 3              4         1       1       0  35.0      1      0  53.1000
# 4              5         0       3       1  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2       1  27.0      0      0  13.0000
# 887          888         1       1       0  19.0      0      0  30.0000
# 888          889         0       3       0   NaN      1      2  23.4500
# 889          890         1       1       1  26.0      0      0  30.0000
# 890          891         0       3       1  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
Data["Age"].median()  #median means total average
# Out:
# 28.0

# %%
Data["Age"]=Data["Age"].fillna(value=28) #To fillnull values ising fillna
Data
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch     Fare  \
# 0              1         0       3       1  22.0      1      0   7.2500
# 1              2         1       1       0  38.0      1      0  71.2833
# 2              3         1       3       0  26.0      0      0   7.9250
# 3              4         1       1       0  35.0      1      0  53.1000
# 4              5         0       3       1  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2       1  27.0      0      0  13.0000
# 887          888         1       1       0  19.0      0      0  30.0000
# 888          889         0       3       0  28.0      1      2  23.4500
# 889          890         1       1       1  26.0      0      0  30.0000
# 890          891         0       3       1  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
Data["Age"].isna().sum()
# Out:
# 0

# %%
Data["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
g=Data.groupby("Survived") #groupby multiple columns
g["Embarked"].value_counts()
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: count, dtype: int64

# %%
from sklearn import preprocessing
lable_encoder=preprocessing.LabelEncoder()
Data["Embarked"]=lable_encoder.fit_transform(Data["Embarked"])
Data["Embarked"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 891, dtype: int32>

# %%
sns.countplot(Data["Embarked"],hue=Data["Survived"])
plt.show()

# %%
Data["Embarked"].value_counts()
# Out:
# Embarked
# 2    644
# 0    168
# 1     77
# 3      2
# Name: count, dtype: int64

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch     Fare  \
# 0              1         0       3       1  22.0      1      0   7.2500
# 1              2         1       1       0  38.0      1      0  71.2833
# 2              3         1       3       0  26.0      0      0   7.9250
# 3              4         1       1       0  35.0      1      0  53.1000
# 4              5         0       3       1  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2       1  27.0      0      0  13.0000
# 887          888         1       1       0  19.0      0      0  30.0000
# 888          889         0       3       0  28.0      1      2  23.4500
# 889          890         1       1       1  26.0      0      0  30.0000
# 890          891         0       3       1  32.0      0      0   7.7500
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# 4           2
# ...

# %%
Data.corr()
# Out:
#              PassengerId  Survived    Pclass    Gender       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.339898  0.083081
# Gender          0.042939 -0.543351  0.131900  1.000000  0.081163 -0.114631
# Age             0.034212 -0.064910 -0.339898  0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096688  0.159651
# Embarked        0.013083 -0.163517  0.157112  0.104057 -0.014205  0.066654
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658  0.013083
# Survived     0.081629  0.257307 -0.163517
# Pclass       0.018443 -0.549500  0.157112
# Gender      -0.245489 -0.182333  0.104057
# ...

# %%
Data.plot(x="Survived",y=["SibSp","Parch"],kind="bar") 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
corr=Data.corr()
corr["Survived"].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.064910
# Embarked      -0.163517
# Pclass        -0.338481
# Gender        -0.543351
# Name: Survived, dtype: float64

# %%
sns.heatmap(Data.corr())
# Out:
# <Axes: >

# %%
correlation['Fare'].sort_values(ascending=False)
correlation['Fare']
# Out:
# PassengerId    0.012658
# Survived       0.257307
# Pclass        -0.549500
# Gender        -0.182333
# Age            0.096688
# SibSp          0.159651
# Parch          0.216225
# Fare           1.000000
# Embarked      -0.221226
# Name: Fare, dtype: float64

# %%
Data.head(5)
# Out:
#    PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch     Fare  \
# 0            1         0       3       1  22.0      1      0   7.2500
# 1            2         1       1       0  38.0      1      0  71.2833
# 2            3         1       3       0  26.0      0      0   7.9250
# 3            4         1       1       0  35.0      1      0  53.1000
# 4            5         0       3       1  35.0      0      0   8.0500
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2

# %%
Data['Family']=Data['SibSp']+Data['Parch']+1
Data=Data.drop(['SibSp','Parch'],axis=1)
Data=Data.drop('PassengerId',axis=1)
Data=Data.drop("Embarked",axis=1)
Data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#      Gender   Age            Ticket     Fare Cabin  Family
# ...
